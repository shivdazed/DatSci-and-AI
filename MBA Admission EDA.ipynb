# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df= pd.read_csv('/storage/emulated/0/Download/kaggler/Admission.csv') 
df.head
# Out:
# <bound method NDFrame.head of      GPA  GMAT Decision
# 0   2.96   596    admit
# 1   3.14   473    admit
# 2   3.22   482    admit
# 3   3.29   527    admit
# 4   3.69   505    admit
# ..   ...   ...      ...
# 80  3.05   399   border
# 81  2.85   483   border
# 82  3.01   453   border
# 83  3.03   414   border
# 84  3.04   446   border
#
# [85 rows x 3 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GPA       85 non-null     float64
#  1   GMAT      85 non-null     int64
#  2   Decision  85 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
df.shape
# Out:
# (85, 3)

# %%
df['Decision'].unique()
# Out:
# array(['admit', 'notadmit', 'border'], dtype=object)

# %%
#checking if null values persists
df.isnull().sum()
# Out:
# GPA         0
# GMAT        0
# Decision    0
# dtype: int64

# %%
#checking for Not A number values 
df.isna().sum()
# Out:
# GPA         0
# GMAT        0
# Decision    0
# dtype: int64

# %%
#Summary of dataset
df.describe()
# Out:
#              GPA        GMAT
# count  85.000000   85.000000
# mean    2.974588  488.447059
# std     0.428995   81.522347
# min     2.130000  313.000000
# 25%     2.600000  425.000000
# 50%     3.010000  482.000000
# 75%     3.300000  538.000000
# max     3.800000  693.000000

# %%
#Visualisations GPA vs decision
sns.relplot(x="Decision", y="GPA", data=df)

# %%
# GMAT vs Decsion graph 
sns.relplot(x="Decision", y="GMAT", data=df)

# %%
#GPA vs GMAT
sns.relplot(x="GPA", y="GMAT",hue='Decision',data=df)

# %%
#GPA VS GMAT
sns.relplot(x="GPA", y="GMAT", hue="Decision", kind="line", data=df)

# %%
#heatmap/Corelation table to show correlation between data
ndf = df.copy()
ndf["Decision"] = ndf["Decision"].astype("category")
ndf["Decision"] = ndf["Decision"].cat.codes

sns.heatmap(ndf.corr()**2 ,annot=True,square=True, cbar_kws= {'orientation': 'horizontal'} )
# Out:
# <AxesSubplot:>
